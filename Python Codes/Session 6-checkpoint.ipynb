# %% [markdown]
# ## strings
# Strings in python are surrounded by either single quotation marks, or double quotation marks.
#
# 'hello' is the same as "hello".
#
# You can display a string literal with the print() function:

# %%
print("Hello")
print('Hello')
# Out:
# Hello
# Hello

# %% [markdown]
# ## Assign String to a Variable
# Assigning a string to a variable is done with the variable name followed by an equal sign and the string:

# %%
a = "Hello"
print(a)
# Out:
# Hello

# %% [markdown]
# ## Multiline Strings
# You can assign a multiline string to a variable by using three quotes:

# %%
a = """Lorem ipsum dolor sit amet,
consectetur adipiscing elit,
sed do eiusmod tempor incididunt
ut labore et dolore magna aliqua."""
print(a)
# Out:
# Lorem ipsum dolor sit amet,
# consectetur adipiscing elit,
# sed do eiusmod tempor incididunt
# ut labore et dolore magna aliqua.

# %%
a = '''Lorem ipsum dolor sit amet,
consectetur adipiscing elit,
sed do eiusmod tempor incididunt
ut labore et dolore magna aliqua.'''
print(a)
# Out:
# Lorem ipsum dolor sit amet,
# consectetur adipiscing elit,
# sed do eiusmod tempor incididunt
# ut labore et dolore magna aliqua.

# %% [markdown]
# ## Strings are Arrays
# Like many other popular programming languages, strings in Python are arrays of bytes representing unicode characters.
#
# However, Python does not have a character data type, a single character is simply a string with a length of 1.
#
# Square brackets can be used to access elements of the string.

# %%
a = "Hello, World!"
print(a[1])
# Out:
# e

# %% [markdown]
# ## Looping Through a String
# Since strings are arrays, we can loop through the characters in a string, with a for loop.

# %%
for x in "banana":
  print(x)
# Out:
# b
# a
# n
# a
# n
# a

# %% [markdown]
# ## String Length
# To get the length of a string, use the len() function.

# %%
a = "Hello, World!"
print(len(a))
# Out:
# 13

# %% [markdown]
# # Check String
# To check if a certain phrase or character is present in a string, we can use the keyword in.

# %%
txt = "The best things in life are free!"
print("free" in txt)
# Out:
# True

# %%
txt = "The best things in life are free!"
if "free" in txt:
  print("Yes, 'free' is present.")
# Out:
# Yes, 'free' is present.

# %% [markdown]
# ## Check if NOT
# To check if a certain phrase or character is NOT present in a string, we can use the keyword not in.

# %%
txt = "The best things in life are free!"
print("expensive" not in txt)
# Out:
# True

# %%
txt = "The best things in life are free!"
if "expensive" not in txt:
  print("No, 'expensive' is NOT present.")
# Out:
# No, 'expensive' is NOT present.

# %% [markdown]
# ## Slicing
# You can return a range of characters by using the slice syntax.
#
# Specify the start index and the end index, separated by a colon, to return a part of the string.

# %%
b = "Hello, World!"
print(b[2:5])
# Out:
# llo

# %% [markdown]
# ## Slice From the Start
# By leaving out the start index, the range will start at the first character:

# %%
b = "Hello, World!"
print(b[:5])
# Out:
# Hello

# %% [markdown]
# ## Slice To the End
# By leaving out the end index, the range will go to the end:

# %%
b = "Hello, World!"
print(b[2:])
# Out:
# llo, World!

# %% [markdown]
# ## Negative Indexing
# Use negative indexes to start the slice from the end of the string:
# Example
# Get the characters:
#
# From: "o" in "World!" (position -5)
#
# To, but not included: "d" in "World!" (position -2):

# %%
b = "Hello, World!"
print(b[-5:-2])
# Out:
# orl

# %% [markdown]
# ## Upper Case
# Example Get your own Python Server
# The upper() method returns the string in upper case:

# %%
a = "Hello, World!"
print(a.upper())
# Out:
# HELLO, WORLD!

# %% [markdown]
# ## Lower Case
# Example:
# The lower() method returns the string in lower case:

# %%
a = "Hello, World!"
print(a.lower())
# Out:
# hello, world!

# %% [markdown]
# ## Remove Whitespace
# Whitespace is the space before and/or after the actual text, and very often you want to remove this space.

# %%
a = " Hello, World! "
print(a.strip())
# Out:
# Hello, World!

# %% [markdown]
# ## Replace String
# Example
# The replace() method replaces a string with another string:

# %%
a = "Hello, World!"
print(a.replace("H", "J"))
# Out:
# Jello, World!

# %% [markdown]
# ## String methods
# capitalize() Method:string.capitalize()

# %%
txt = "python is FUN!"

x = txt.capitalize()

print (x)
# Out:
# Python is fun!

# %% [markdown]
# ![strings%20function%20.png](attachment:strings%20function%20.png)

# %% [markdown]
# ## Strings Methods
# ![string%202.png](attachment:string%202.png)

# %%
l1=[1,4,5,0,3,2]
l1.sort()

# %%
l1
# Out:
# [5, 4, 3, 2, 1, 0, 22, 44, 66, 80, 80, 80, [55, 77], 22, 44, 66]

# %%
l1.sort(reverse=True)
l1
# Out:
# [5, 4, 3, 2, 1, 0]

# %%
l1.extend([22,44,66])
l1
# Out:
# [5, 4, 3, 2, 1, 0, 22, 44, 66, 80, 80, 80, [55, 77], 22, 44, 66]

# %%
l1.pop()
# Out:
# 66

# %%
l1.insert(-1,80)
l1
# Out:
# [5, 4, 3, 2, 1, 0, 22, 44, 66, 80, 80, 80, [55, 77]]

# %%
l1
# Out:
# [5, 4, 3, 2, 1, 0, 22, 44, 66, 80, 80, 80, [55, 77], 22, 44]

# %%
l1.pop(12)
# Out:
# [55, 77]

# %%
l1.count(80)
# Out:
# 3

# %%
l2=l1.reverse
print(l2)
# Out:
# <built-in method reverse of list object at 0x00000286FAD9C540>

# %%
l3=[1,2,3]
a=int(input())
b=int(input())
l3.extend([a,b])
l3
# Out:
# 4
# 5
# [1, 2, 3, 4, 5]

# %%
c=int(input())
d=int(input())
l3.append(c)
l3.append(d)
l3
# Out:
# 8
# 9
# [1, 2, 3, 4, 5, 8, 9]

# %%
l1=[1,2,3,4]
l1[::-1]
# Out:
# [4, 3, 2, 1]
